# %%
import pandas as pd
import numpy as np

# read dataset into pandas dataframe
df_items = pd.read_csv('items-Copy1.csv')
# replace field that's entirely space (or empty) with NaN
print(df_items.replace(np.nan, '', regex=True))
df_items = df_items.replace(np.nan, '', regex=True)

# print out top 5 rows
print(df_items.head())
# Out:
#                                             url  identifier  \
# 0     https://mith.umd.edu/irads/api/items/6456        3186
# 1     https://mith.umd.edu/irads/api/items/6457        1084
# 2     https://mith.umd.edu/irads/api/items/6458        3135
# 3     https://mith.umd.edu/irads/api/items/6459        3167
# 4     https://mith.umd.edu/irads/api/items/6460        1139
# ...                                         ...         ...
# 3007  https://mith.umd.edu/irads/api/items/9463        2430
# 3008  https://mith.umd.edu/irads/api/items/9464        1255
# 3009  https://mith.umd.edu/irads/api/items/9465        1256
# 3010  https://mith.umd.edu/irads/api/items/9466        2425
# 3011  https://mith.umd.edu/irads/api/items/9467        1254
#
#                                           title  \
# 0     Black American racial experience is real…
# 1     The best costume for Halloween worth pos…
# 2     Keep on whining and crying for your pres…
# 3     End the whining and crying, end the riot…
# 4     Black girls are the definition of nation…
# ...                                         ...
# 3007            New ideas, old values. Like us!
# 3008  Secured borders are a national priority.…
# 3009  Secured borders should be a top priority…
# 3010                      Bernie for president!
# 3011  Secured borders are a national priority.…
#
#                                             description  \
# 0     Black American racial experience is real. We s...
# 1     The best costume for Halloween worth posting. ...
# 2     Keep on whining and crying for your president,...
# 3     End the whining and crying, end the riots with...
# 4     Black girls are the definition of national gre...
# ...                                                 ...
# 3007                    New ideas, old values. Like us!
# 3008  Secured borders are a national priority. We ne...
# 3009  Secured borders should be a top priority. We n...
# 3010                              Bernie for president!
# 3011  Secured borders are a national priority. Ameri...
#
#                                                   image currency      cost  \
# 0     https://mith.umd.edu/irads/files/original/f255...      RUB   1050.77
# 1     https://mith.umd.edu/irads/files/original/f72d...      RUB    500.00
# 2     https://mith.umd.edu/irads/files/original/ccce...      RUB     69.00
# 3     https://mith.umd.edu/irads/files/original/11f2...      RUB     25.39
# 4     https://mith.umd.edu/irads/files/original/f178...      RUB    395.08
# ...                                                 ...      ...       ...
# 3007  https://mith.umd.edu/irads/files/original/5c5e...      RUB  36629.80
# 3008  https://mith.umd.edu/irads/files/original/4e71...               0.00
# 3009  https://mith.umd.edu/irads/files/original/d84a...      RUB   1625.79
# 3010  https://mith.umd.edu/irads/files/original/dc10...               0.00
# 3011  https://mith.umd.edu/irads/files/original/8ef3...      RUB    204.19
#
#                         created                      ended  impressions  ...  \
# 0     2016-11-14T04:10:27-08:00                                     396  ...
# 1     2016-11-03T08:10:07-07:00  2016-11-10T07:10:07-08:00        64032  ...
# 2     2016-11-11T03:57:07-08:00  2016-11-14T03:57:07-08:00         4514  ...
# 3     2016-11-15T04:55:06-08:00  2016-11-16T04:55:06-08:00          566  ...
# 4     2016-11-30T07:15:04-08:00  2016-12-01T07:15:04-08:00        29629  ...
# ...                         ...                        ...          ...  ...
# 3007  2016-07-14T00:58:10-07:00                                   49920  ...
# 3008  2017-07-16T23:37:07-07:00  2017-07-19T15:51:23-07:00            0  ...
# 3009  2017-07-16T23:38:24-07:00  2017-07-19T15:51:23-07:00         1706  ...
# 3010  2016-07-14T01:00:02-07:00  2016-06-08T05:53:54-07:00            0  ...
# 3011  2017-07-16T15:51:18-07:00  2017-07-19T15:51:23-07:00          184  ...
#
#      residence match location politics multicultural affinity industry  \
# 0
# 1
# 2
# 3
# 4
# ...        ...   ...      ...      ...                    ...      ...
# 3007
# 3008
# 3009
# 3010
# 3011
#
#      employer clicks                                       facebook url  \
# 0                 32    https://www.facebook.com/ProtectBIackGunOwners/
# 1              11056  https://www.facebook.com/Blacktivist-128371547...
# 2                540  https://www.facebook.com/Woke-B|acks-294234600...
# 3                115  https://www.facebook.com/Woke-Blacks-294234600...
# 4               4433             https://www.facebook.com/blacktivists/
# ...       ...    ...                                                ...
# 3007            4799              https://www.facebook.com/bornliberall
# 3008               0          https://www.facebook.com/Secured.Borders/
# 3009             194          https://www.facebook.com/Secured.Borders/
# 3010               0  https://www.facebook.com/Born-LiberaI-52262856...
# 3011              16          https://www.facebook.com/Secured.Borders/
#
#                                                     tag
# 0     2nd Amendment|Black guns matter|civil rights|F...
# 1     Anger|black|Blacktivist|civil rights|equality|...
# 2     Anger|blacklivesmatter|brown|can't trust the C...
# 3     Anger|black|blacklivesmatter|can't trust the C...
# 4     black|Blacktivist|gender|race|racial identitie...
# ...                                                 ...
# 3007  empowerment|equality|Liberal|world of possibil...
# 3008  badge|barriers|blue|borders|Conservative|Const...
# 3009  badge|barriers|blue|borders|Conservative|Const...
# 3010                       Bernie|Democrat|Liberal|woke
# 3011  badge|barriers|blue|borders|Conservative|Const...
#
# [3012 rows x 24 columns]
#                                          url  identifier  \
# 0  https://mith.umd.edu/irads/api/items/6456        3186
# 1  https://mith.umd.edu/irads/api/items/6457        1084
# 2  https://mith.umd.edu/irads/api/items/6458        3135
# 3  https://mith.umd.edu/irads/api/items/6459        3167
# 4  https://mith.umd.edu/irads/api/items/6460        1139
#
#                                        title  \
# 0  Black American racial experience is real…
# 1  The best costume for Halloween worth pos…
# 2  Keep on whining and crying for your pres…
# 3  End the whining and crying, end the riot…
# 4  Black girls are the definition of nation…
#
#                                          description  \
# 0  Black American racial experience is real. We s...
# 1  The best costume for Halloween worth posting. ...
# 2  Keep on whining and crying for your president,...
# 3  End the whining and crying, end the riots with...
# 4  Black girls are the definition of national gre...
#
#                                                image currency     cost  \
# 0  https://mith.umd.edu/irads/files/original/f255...      RUB  1050.77
# 1  https://mith.umd.edu/irads/files/original/f72d...      RUB   500.00
# 2  https://mith.umd.edu/irads/files/original/ccce...      RUB    69.00
# 3  https://mith.umd.edu/irads/files/original/11f2...      RUB    25.39
# 4  https://mith.umd.edu/irads/files/original/f178...      RUB   395.08
#
#                      created                      ended  impressions  ...  \
# 0  2016-11-14T04:10:27-08:00                                     396  ...
# 1  2016-11-03T08:10:07-07:00  2016-11-10T07:10:07-08:00        64032  ...
# 2  2016-11-11T03:57:07-08:00  2016-11-14T03:57:07-08:00         4514  ...
# 3  2016-11-15T04:55:06-08:00  2016-11-16T04:55:06-08:00          566  ...
# 4  2016-11-30T07:15:04-08:00  2016-12-01T07:15:04-08:00        29629  ...
#
#   residence match location politics multicultural affinity industry employer  \
# 0
# 1
# 2
# 3
# 4
#
#   clicks                                       facebook url  \
# 0     32    https://www.facebook.com/ProtectBIackGunOwners/
# 1  11056  https://www.facebook.com/Blacktivist-128371547...
# 2    540  https://www.facebook.com/Woke-B|acks-294234600...
# 3    115  https://www.facebook.com/Woke-Blacks-294234600...
# 4   4433             https://www.facebook.com/blacktivists/
#
#                                                  tag
# 0  2nd Amendment|Black guns matter|civil rights|F...
# 1  Anger|black|Blacktivist|civil rights|equality|...
# 2  Anger|blacklivesmatter|brown|can't trust the C...
# 3  Anger|black|blacklivesmatter|can't trust the C...
# 4  black|Blacktivist|gender|race|racial identitie...
#
# [5 rows x 24 columns]

# %%
# df_clicks -> all items sorted in descending order by clicks
# most clicked on items are at the top
df_clicks = df_items.sort_values(by='clicks', ascending=False)

# let's see the top 10 clicked on tags
print(df_clicks[['tag','clicks']].head(10))
# Out:
#                                                     tag  clicks
# 530   Back the Badge|badge|blue|crime|illustration|J...   73063
# 413   bald eagle|Being Patriotic|blue|Joy|nation|non...   72043
# 2388  Brown Power|class|green|illustration|Joy|natio...   56405
# 1514                  Blacktivist|non-partisan|redacted   49197
# 544   blue|Confederacy|Confederate flag|empowerment|...   40134
# 2326  black|blue|common folks|Joy|orange|photograph|...   33444
# 767   Anger|barriers|black|Blacktivist|illustration|...   31413
# 1877  black|Brown Power|Joy|non-partisan|orange|phot...   30775
# 1346  Army of Jesus|blue|darkness and light|illustra...   28137
# 1530  black|Blacktivist|famous person|gender|Joy|pho...   26964

# %%
# df_impressions -> all items sorted in descending order by impressions
# most impression items are at the top
df_impressions = df_items.sort_values(by='impressions', ascending=False)

# let's see the top 10 clicked on tags
print(df_impressions[['tag','impressions']].head(10))
# Out:
#                                                     tag  impressions
# 530   Back the Badge|badge|blue|crime|illustration|J...      1334544
# 2388  Brown Power|class|green|illustration|Joy|natio...       968768
# 2326  black|blue|common folks|Joy|orange|photograph|...       752179
# 767   Anger|barriers|black|Blacktivist|illustration|...       530762
# 413   bald eagle|Being Patriotic|blue|Joy|nation|non...       529205
# 544   blue|Confederacy|Confederate flag|empowerment|...       511224
# 1514                  Blacktivist|non-partisan|redacted       501552
# 1988  black|Blacktivist|common folks|red|redacted|Su...       489186
# 828   black|commercial|Joy|non-partisan|pray4police|...       418904
# 931   Anger|black|civil rights|common folks|Facebook...       371295

# %%
# let's get the top 50 clicked on tags
top50_tags_clicks = df_clicks[['tag']].head(50)
print(top50_tags_clicks)
# Out:
#                                                     tag
# 530   Back the Badge|badge|blue|crime|illustration|J...
# 413   bald eagle|Being Patriotic|blue|Joy|nation|non...
# 2388  Brown Power|class|green|illustration|Joy|natio...
# 1514                  Blacktivist|non-partisan|redacted
# 544   blue|Confederacy|Confederate flag|empowerment|...
# 2326  black|blue|common folks|Joy|orange|photograph|...
# 767   Anger|barriers|black|Blacktivist|illustration|...
# 1877  black|Brown Power|Joy|non-partisan|orange|phot...
# 1346  Army of Jesus|blue|darkness and light|illustra...
# 1530  black|Blacktivist|famous person|gender|Joy|pho...
# 1988  black|Blacktivist|common folks|red|redacted|Su...
# 631   2nd Amendment|black|Defend the 2nd|gun|guns|il...
# 2573  blacklivesmatter|civil rights|class|equality|p...
# 1490                               Blacktivist|redacted
# 1408  Blacktivist|Humor|race|racial identities|redacted
# 2044  Anger|badge|black|Blacktivist|civil rights|com...
# 294     illustration|Joy|LGBT United|LGBTQ|Love|rainbow
# 2393  black|crime|Defend the 2nd|guns|illustration|J...
# 492   Army of Jesus|blue|illustration|Love|nation|no...
# 150   Blacktivist|brown|common folks|Love|photograph...
# 2862  blacklivesmatter|empowerment|justice|race|stay...
# 1222  Anger|black|Fear|green|guns|illegal immigratio...
# 226   blue|Heart of Texas|illustration|Joy|red|Texas...
# 1706  Anger|Brown Power|Fear|foreign policy|racial i...
# 644   blue|common folks|Joy|non-partisan|photograph|...
# 2166         black|Brown Power|photograph|red|white|wut
# 2213  Anger|black|non-partisan|photograph|red|South ...
# 931   Anger|black|civil rights|common folks|Facebook...
# 1090  black|Blacktivist|non-partisan|photograph|popu...
# 1383  Anger|black|Blacktivist|darkness and light|Joy...
# 1549          Brown Power|gender|meme|racial identities
# 2983  blue|patriotism|red|religion|religious figure|...
# 1073  barriers|borders|immigration|invader|non-parti...
# 2057  badge|blue|brown|civil rights|common folks|cow...
# 1572  Blacktivist|blue|brown|gender|Joy|race|racial ...
# 1687  Anger|black|Blacktivist|class|foreign policy|I...
# 1517  black|Blacktivist|blue|common folks|gender|Joy...
# 748   black|civil rights|illustration|race|racial id...
# 1341               black|Blacktivist|Love|race|redacted
# 1463  Anger|black|Blacktivist|brown|equality|protest...
# 322   black|Black lives|blacklivesmatter|civil right...
# 2497  bald eagle|Being Patriotic|blue|Joy|painting|p...
# 68         black|BM|police brutality|video|white|yellow
# 11    Blacktivist|civil rights|common folks|darkness...
# 1898  Blacktivist|brown|common folks|Joy|photograph|...
# 2717  black|civil rights|commercial|common folks|emp...
# 1     Anger|black|Blacktivist|civil rights|equality|...
# 1446  Brown Power|immigration|Joy|nation|race|racial...
# 2541  Anger|black|blacklivesmatter|blue|civil rights...
# 964   black|Joy|photograph|race|racial identities|re...

# %%
# let's get the top 50 impressioned tags
top50_tags_impressions = df_impressions[['tag']].head(50)
print(top50_tags_impressions)
# Out:
#                                                     tag
# 530   Back the Badge|badge|blue|crime|illustration|J...
# 2388  Brown Power|class|green|illustration|Joy|natio...
# 2326  black|blue|common folks|Joy|orange|photograph|...
# 767   Anger|barriers|black|Blacktivist|illustration|...
# 413   bald eagle|Being Patriotic|blue|Joy|nation|non...
# 544   blue|Confederacy|Confederate flag|empowerment|...
# 1514                  Blacktivist|non-partisan|redacted
# 1988  black|Blacktivist|common folks|red|redacted|Su...
# 828   black|commercial|Joy|non-partisan|pray4police|...
# 931   Anger|black|civil rights|common folks|Facebook...
# 1346  Army of Jesus|blue|darkness and light|illustra...
# 2573  blacklivesmatter|civil rights|class|equality|p...
# 644   blue|common folks|Joy|non-partisan|photograph|...
# 631   2nd Amendment|black|Defend the 2nd|gun|guns|il...
# 2213  Anger|black|non-partisan|photograph|red|South ...
# 1490                               Blacktivist|redacted
# 748   black|civil rights|illustration|race|racial id...
# 492   Army of Jesus|blue|illustration|Love|nation|no...
# 2393  black|crime|Defend the 2nd|guns|illustration|J...
# 1408  Blacktivist|Humor|race|racial identities|redacted
# 46    black|empowerment|Joy|Pan-African roots MOVE|r...
# 1877  black|Brown Power|Joy|non-partisan|orange|phot...
# 1194  Anger|black|crime|Don't Shoot|guns|illustratio...
# 2862  blacklivesmatter|empowerment|justice|race|stay...
# 322   black|Black lives|blacklivesmatter|civil right...
# 11    Blacktivist|civil rights|common folks|darkness...
# 2856  Democrat|empowerment|equality|gender|LGBTQ|Lib...
# 2195  black|blue|common folks|Joy|photograph|race|ra...
# 964   black|Joy|photograph|race|racial identities|re...
# 226   blue|Heart of Texas|illustration|Joy|red|Texas...
# 294     illustration|Joy|LGBT United|LGBTQ|Love|rainbow
# 1415  blue|Confederacy|Confederate flag|illustration...
# 835   _american.made|black|city on a hill|Joy|MAGA|n...
# 2983  blue|patriotism|red|religion|religious figure|...
# 1341               black|Blacktivist|Love|race|redacted
# 1383  Anger|black|Blacktivist|darkness and light|Joy...
# 150   Blacktivist|brown|common folks|Love|photograph...
# 2044  Anger|badge|black|Blacktivist|civil rights|com...
# 2790  black|freedom|liberty|nation|patriotism|soldie...
# 1530  black|Blacktivist|famous person|gender|Joy|pho...
# 2860  blacklivesmatter|empowerment|justice|race|stay...
# 1077  badge|black|Black Matters|Fear|non-partisan|ph...
# 1706  Anger|Brown Power|Fear|foreign policy|racial i...
# 2296  blue|Conservative|illustration|REAL AMERICA|re...
# 1687  Anger|black|Blacktivist|class|foreign policy|I...
# 1090  black|Blacktivist|non-partisan|photograph|popu...
# 2352  black|blue|civil rights|common folks|illustrat...
# 2125  black|brown|Brown Power|civil rights|common fo...
# 2725  alllivesmatter|crime|equality|gun|police bruta...
# 1063  Anger|black|blue|crime|darkness and light|Don'...

# %%
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
import collections
import re

def word_sorter(df_to_use):
    
    '''
    Input: 
        df_to_use: df of top clicked on tags in this case
    Output:
        sorted list of tuples representing key value pairs of word freq.
        
    Task:
        Goes through all tags and separates them into words.
        After, it will note their frequencies in descending order.
    '''
    
    # regular expression tokenizer
    tokenizer = RegexpTokenizer(r'\w+')
    # regex to get rid of non alphanumeric characters
    regex = re.compile('[^a-zA-Z]')
    
    # remove | delimiters as well as non-alphanumeric characters
    # combine words into one string
    words = []
    for word in df_to_use['tag']:
        word = regex.sub(' ', word)
        words.append(word.lower()) # lowercase as to avoid any case issues
    
    # join all words into one string
    words = ' '.join(words)
    
    # find all unique words 
    tokens = tokenizer.tokenize(words)
    print(str(len(tokens)) + " unique words")
    
    # remove stop words
    stop_words = set(stopwords.words('english'))
    
    # create al ist that does not contain stop words or numbers
    filtered_tag_tokens = []
    for word in tokens:
        if word not in stop_words:
            filtered_tag_tokens.append(word)
    print(str(len(filtered_tag_tokens)) + " unique non stopwords")
    
    # remove all words not in filtered tokens and remove all digits as well
    dic={}
    for word in words.split(" "):
        if word in filtered_tag_tokens and not word.isdigit():
            if word in dic:
                dic[word]=dic[word]+1
            else:
                dic[word]=1
                
    # sort words by number of occurences or frequency
    sorted_tag_words = sorted(dic.items(), key=lambda kv: (kv[1],kv[0]), reverse=True)
    return sorted_tag_words

# %%
word_sorter(top50_tags_clicks)
# Out:
# 631 unique words
# 603 unique non stopwords
# [('racial', 32),
#  ('white', 29),
#  ('race', 26),
#  ('black', 26),
#  ('joy', 23),
#  ('red', 20),
#  ('identities', 20),
#  ('photograph', 19),
#  ('blacktivist', 18),
#  ('blue', 14),
#  ('tensions', 12),
#  ('illustration', 12),
#  ('folks', 11),
#  ('common', 11),
#  ('brown', 11),
#  ('anger', 11),
#  ('rights', 10),
#  ('civil', 10),
#  ('police', 9),
#  ('partisan', 9),
#  ('non', 9),
#  ('nation', 9),
#  ('brutality', 9),
#  ('text', 8),
#  ('sadness', 8),
#  ('redacted', 8),
#  ('patriotism', 7),
#  ('flag', 7),
#  ('video', 6),
#  ('u', 6),
#  ('power', 6),
#  ('love', 6),
#  ('yellow', 5),
#  ('woke', 5),
#  ('justice', 5),
#  ('guns', 5),
#  ('fear', 5),
#  ('equality', 5),
#  ('sacred', 4),
#  ('protester', 4),
#  ('people', 4),
#  ('light', 4),
#  ('immigration', 4),
#  ('gender', 4),
#  ('darkness', 4),
#  ('crime', 4),
#  ('blacklivesmatter', 4),
#  ('badge', 4),
#  ('united', 3),
#  ('soldiers', 3),
#  ('religious', 3),
#  ('religion', 3),
#  ('orange', 3),
#  ('nd', 3),
#  ('meme', 3),
#  ('gun', 3),
#  ('green', 3),
#  ('figure', 3),
#  ('empowerment', 3),
#  ('class', 3),
#  ('wut', 2),
#  ('world', 2),
#  ('war', 2),
#  ('texas', 2),
#  ('surprise', 2),
#  ('south', 2),
#  ('purple', 2),
#  ('possibilities', 2),
#  ('policy', 2),
#  ('patriotic', 2),
#  ('lgbtq', 2),
#  ('jesus', 2),
#  ('invader', 2),
#  ('humor', 2),
#  ('foreign', 2),
#  ('eagle', 2),
#  ('defend', 2),
#  ('borders', 2),
#  ('blacks', 2),
#  ('barriers', 2),
#  ('bald', 2),
#  ('army', 2),
#  ('williams', 1),
#  ('veterans', 1),
#  ('terrorism', 1),
#  ('stop', 1),
#  ('staystrong', 1),
#  ('shoot', 1),
#  ('security', 1),
#  ('secured', 1),
#  ('rainbow', 1),
#  ('popular', 1),
#  ('person', 1),
#  ('painting', 1),
#  ('lives', 1),
#  ('lgbt', 1),
#  ('kalvin', 1),
#  ('islamophobia', 1),
#  ('illegal', 1),
#  ('heart', 1),
#  ('graduation', 1),
#  ('first', 1),
#  ('famous', 1),
#  ('facebook', 1),
#  ('culture', 1),
#  ('cowboy', 1),
#  ('confederate', 1),
#  ('confederacy', 1),
#  ('commercial', 1),
#  ('come', 1),
#  ('bm', 1),
#  ('back', 1),
#  ('amendment', 1)]

# %%
word_sorter(top50_tags_impressions)
# Out:
# 606 unique words
# 580 unique non stopwords
# [('white', 30),
#  ('black', 29),
#  ('racial', 28),
#  ('race', 25),
#  ('joy', 22),
#  ('red', 21),
#  ('illustration', 17),
#  ('identities', 17),
#  ('photograph', 16),
#  ('blue', 14),
#  ('blacktivist', 13),
#  ('tensions', 11),
#  ('police', 11),
#  ('partisan', 11),
#  ('non', 11),
#  ('nation', 10),
#  ('folks', 10),
#  ('common', 10),
#  ('brutality', 10),
#  ('anger', 9),
#  ('rights', 8),
#  ('redacted', 8),
#  ('civil', 8),
#  ('patriotism', 7),
#  ('woke', 6),
#  ('sadness', 6),
#  ('love', 6),
#  ('flag', 6),
#  ('crime', 6),
#  ('brown', 6),
#  ('text', 5),
#  ('sacred', 5),
#  ('religion', 5),
#  ('light', 5),
#  ('empowerment', 5),
#  ('darkness', 5),
#  ('video', 4),
#  ('united', 4),
#  ('u', 4),
#  ('religious', 4),
#  ('power', 4),
#  ('guns', 4),
#  ('figure', 4),
#  ('fear', 4),
#  ('blacklivesmatter', 4),
#  ('badge', 4),
#  ('south', 3),
#  ('protester', 3),
#  ('people', 3),
#  ('nd', 3),
#  ('justice', 3),
#  ('green', 3),
#  ('equality', 3),
#  ('class', 3),
#  ('blacks', 3),
#  ('williams', 2),
#  ('texas', 2),
#  ('surprise', 2),
#  ('staystrong', 2),
#  ('soldiers', 2),
#  ('shoot', 2),
#  ('rainbow', 2),
#  ('purple', 2),
#  ('policy', 2),
#  ('orange', 2),
#  ('lgbtq', 2),
#  ('kalvin', 2),
#  ('jesus', 2),
#  ('invader', 2),
#  ('gun', 2),
#  ('gender', 2),
#  ('foreign', 2),
#  ('defend', 2),
#  ('confederate', 2),
#  ('confederacy', 2),
#  ('army', 2),
#  ('yellow', 1),
#  ('wut', 1),
#  ('world', 1),
#  ('war', 1),
#  ('veterans', 1),
#  ('trump', 1),
#  ('terrorism', 1),
#  ('roots', 1),
#  ('real', 1),
#  ('prison', 1),
#  ('pray', 1),
#  ('possibilities', 1),
#  ('popular', 1),
#  ('person', 1),
#  ('patriotic', 1),
#  ('pan', 1),
#  ('move', 1),
#  ('millennials', 1),
#  ('meme', 1),
#  ('matters', 1),
#  ('maga', 1),
#  ('made', 1),
#  ('lives', 1),
#  ('liberty', 1),
#  ('liberal', 1),
#  ('lgbt', 1),
#  ('islamophobia', 1),
#  ('immigration', 1),
#  ('humor', 1),
#  ('hill', 1),
#  ('heart', 1),
#  ('graduation', 1),
#  ('freedom', 1),
#  ('famous', 1),
#  ('facebook', 1),
#  ('eagle', 1),
#  ('democrat', 1),
#  ('culture', 1),
#  ('conservative', 1),
#  ('commercial', 1),
#  ('city', 1),
#  ('barriers', 1),
#  ('bald', 1),
#  ('back', 1),
#  ('american', 1),
#  ('america', 1),
#  ('amendment', 1),
#  ('alllivesmatter', 1),
#  ('african', 1)]

# %%
#Bar Chart 
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

def word_frequency_graph(df_to_use, title, number_words):
    
    '''
    Input:
        df_to_use: the df we want to get our tags from to plot
        title: title name of plot
        number_words: number of most freq. words to plot
        
    '''
    
    # get first number_words from word_sorter
    words = word_sorter(df_to_use)[:number_words]
    count_words = []
    actual_word = []
    
    # make two lists of words representing the words and counts for plotting
    for word, count in words:
        count_words.append(count)
        actual_word.append(word)
    
    # plot code
    plt.figure(figsize=(number_words - 2, number_words - 2)) # figsize dynamically resizes with number_words
    plt.bar(actual_word, count_words, align='center', alpha=0.5)
    plt.ylabel('Frequency')
    plt.title(str(title) + ' Word Frequency')
    plt.tick_params(axis='x', which='major', pad=15)
    plt.xticks(rotation=45) # rotate tick labels to avoid overlapping
    
    plt.show()

# %%
word_frequency_graph(top50_tags_clicks, 'Tags', 20) # display most frequent tags in top 50 rows based on clicks
# Out:
# 631 unique words
# 603 unique non stopwords

# %%
word_frequency_graph(top50_tags_impressions, 'Tags', 20) # display most frequent tags in top 50 rows based on impressions
# Out:
# 606 unique words
# 580 unique non stopwords

# %%
# Take rows with tags 'black', 'white', both or neither and label them as such
# 'black' = 0, 'white' = 1, both = 2, neither = 3
labels_list_word = []
labels_list_numerical = []

for i, row in df_items.iterrows():
    row['tag'] = row['tag'].lower()
    if 'black' in row['tag'] and not 'white' in row['tag']: #and 'white' in row['tag']:
        labels_list_word.append('black') # black
        labels_list_numerical.append(0) # 0
    elif not 'black' in row['tag'] and 'white' in row['tag']:
        labels_list_word.append('white') # white
        labels_list_numerical.append(1) # 1
    elif 'black' in row['tag'] and 'white' in row['tag']:
        labels_list_word.append('both') # both
        labels_list_numerical.append(2) # 2
    else:
        labels_list_word.append('neither') # neither
        labels_list_numerical.append(3) # 3
        
df_items['label word'] = labels_list_word # append labels_list_word to df_items with column header 'label word'
df_items['label numerical'] = labels_list_numerical # append labels_list_numerical to df_items with column header 'label numerical'

print(df_items)
# Out:
#                                             url  identifier  \
# 0     https://mith.umd.edu/irads/api/items/6456        3186
# 1     https://mith.umd.edu/irads/api/items/6457        1084
# 2     https://mith.umd.edu/irads/api/items/6458        3135
# 3     https://mith.umd.edu/irads/api/items/6459        3167
# 4     https://mith.umd.edu/irads/api/items/6460        1139
# ...                                         ...         ...
# 3007  https://mith.umd.edu/irads/api/items/9463        2430
# 3008  https://mith.umd.edu/irads/api/items/9464        1255
# 3009  https://mith.umd.edu/irads/api/items/9465        1256
# 3010  https://mith.umd.edu/irads/api/items/9466        2425
# 3011  https://mith.umd.edu/irads/api/items/9467        1254
#
#                                           title  \
# 0     Black American racial experience is real…
# 1     The best costume for Halloween worth pos…
# 2     Keep on whining and crying for your pres…
# 3     End the whining and crying, end the riot…
# 4     Black girls are the definition of nation…
# ...                                         ...
# 3007            New ideas, old values. Like us!
# 3008  Secured borders are a national priority.…
# 3009  Secured borders should be a top priority…
# 3010                      Bernie for president!
# 3011  Secured borders are a national priority.…
#
#                                             description  \
# 0     Black American racial experience is real. We s...
# 1     The best costume for Halloween worth posting. ...
# 2     Keep on whining and crying for your president,...
# 3     End the whining and crying, end the riots with...
# 4     Black girls are the definition of national gre...
# ...                                                 ...
# 3007                    New ideas, old values. Like us!
# 3008  Secured borders are a national priority. We ne...
# 3009  Secured borders should be a top priority. We n...
# 3010                              Bernie for president!
# 3011  Secured borders are a national priority. Ameri...
#
#                                                   image currency      cost  \
# 0     https://mith.umd.edu/irads/files/original/f255...      RUB   1050.77
# 1     https://mith.umd.edu/irads/files/original/f72d...      RUB    500.00
# 2     https://mith.umd.edu/irads/files/original/ccce...      RUB     69.00
# 3     https://mith.umd.edu/irads/files/original/11f2...      RUB     25.39
# 4     https://mith.umd.edu/irads/files/original/f178...      RUB    395.08
# ...                                                 ...      ...       ...
# 3007  https://mith.umd.edu/irads/files/original/5c5e...      RUB  36629.80
# 3008  https://mith.umd.edu/irads/files/original/4e71...               0.00
# 3009  https://mith.umd.edu/irads/files/original/d84a...      RUB   1625.79
# 3010  https://mith.umd.edu/irads/files/original/dc10...               0.00
# 3011  https://mith.umd.edu/irads/files/original/8ef3...      RUB    204.19
#
#                         created                      ended  impressions  ...  \
# 0     2016-11-14T04:10:27-08:00                                     396  ...
# 1     2016-11-03T08:10:07-07:00  2016-11-10T07:10:07-08:00        64032  ...
# 2     2016-11-11T03:57:07-08:00  2016-11-14T03:57:07-08:00         4514  ...
# 3     2016-11-15T04:55:06-08:00  2016-11-16T04:55:06-08:00          566  ...
# 4     2016-11-30T07:15:04-08:00  2016-12-01T07:15:04-08:00        29629  ...
# ...                         ...                        ...          ...  ...
# 3007  2016-07-14T00:58:10-07:00                                   49920  ...
# 3008  2017-07-16T23:37:07-07:00  2017-07-19T15:51:23-07:00            0  ...
# 3009  2017-07-16T23:38:24-07:00  2017-07-19T15:51:23-07:00         1706  ...
# 3010  2016-07-14T01:00:02-07:00  2016-06-08T05:53:54-07:00            0  ...
# 3011  2017-07-16T15:51:18-07:00  2017-07-19T15:51:23-07:00          184  ...
#
#      politics multicultural affinity industry employer clicks  \
# 0                                                          32
# 1                                                       11056
# 2                                                         540
# 3                                                         115
# 4                                                        4433
# ...       ...                    ...      ...      ...    ...
# 3007                                                     4799
# 3008                                                        0
# 3009                                                      194
# 3010                                                        0
# 3011                                                       16
#
#                                            facebook url  \
# 0       https://www.facebook.com/ProtectBIackGunOwners/
# 1     https://www.facebook.com/Blacktivist-128371547...
# 2     https://www.facebook.com/Woke-B|acks-294234600...
# 3     https://www.facebook.com/Woke-Blacks-294234600...
# 4                https://www.facebook.com/blacktivists/
# ...                                                 ...
# 3007              https://www.facebook.com/bornliberall
# 3008          https://www.facebook.com/Secured.Borders/
# 3009          https://www.facebook.com/Secured.Borders/
# 3010  https://www.facebook.com/Born-LiberaI-52262856...
# 3011          https://www.facebook.com/Secured.Borders/
#
#                                                     tag label label word  \
# 0     2nd Amendment|Black guns matter|civil rights|F...     0      black
# 1     Anger|black|Blacktivist|civil rights|equality|...     0      black
# 2     Anger|blacklivesmatter|brown|can't trust the C...     0      black
# 3     Anger|black|blacklivesmatter|can't trust the C...     2       both
# 4     black|Blacktivist|gender|race|racial identitie...     0      black
# ...                                                 ...   ...        ...
# 3007  empowerment|equality|Liberal|world of possibil...     3    neither
# 3008  badge|barriers|blue|borders|Conservative|Const...     1      white
# 3009  badge|barriers|blue|borders|Conservative|Const...     1      white
# 3010                       Bernie|Democrat|Liberal|woke     3    neither
# 3011  badge|barriers|blue|borders|Conservative|Const...     1      white
#
#      label numerical
# 0                  0
# 1                  0
# 2                  0
# 3                  2
# 4                  0
# ...              ...
# 3007               3
# 3008               1
# 3009               1
# 3010               3
# 3011               1
#
# [3012 rows x 27 columns]

# %%
pd.set_option('display.max_colwidth', -1) # set display options to display entire non-turnicated contents
print(df_items[['label word', 'description']].head(10))
# Out:
#   label word  \
# 0  black
# 1  black
# 2  black
# 3  both
# 4  black
# 5  black
# 6  both
# 7  black
# 8  both
# 9  black
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      description
# 0  Black American racial experience is real. We support the 2nd ammendment\nfor our safety.
# 1  The best costume for Halloween worth posting. Power to the People!
# 2  Keep on whining and crying for your president, ooh, who wasn't elected.\nImma take care of my kids.\n\nI'll keep grinding for them, to make sure the get the best education.\nTo ensure they dress well and eat healthy food.\nAnd I'm gon tell you to do the same thing.\n\nDon't waste time on an "afterparty" you wouldn't have been invited to!\n\n#word #wakeup #organize #joshuabeal #altonsterling #TerenceCrutCher\n#westandtogether #blacklivesmatter #unite4justice #hovem ber8\n#electi0h52016 #black #melanin #blackisbeautiful #blacklivesmatter\n#blackgirlmagic #USA #blackahdproud #democrat #republioan\n#Africanamerican #unite4justice #vote #breakingnews
# 3  End the whining and crying, end the riots with these same white\npeople(democrats), who will not march with you when your son, daughter or\nloved one gets shot for being Black.\n\nI opted out of the elections and i had many Black people all up in my case,\ntelling me how i was wrong and how i needed to make my vote count for Mrs.\nClinton, all just to make sure Trump doesn't become president.\n\nWell now all i want to say is get over Trump and Clinton, they are rich white\npeople, the elite who were born into and are a part of the system.\n\nI dream of liberation, not staying a slave under Hillary or Trump, so forget\nyour Childish rioting, no one has shot!\n\n#wakeup #organize #joshuabeal #altonsterling #TerenceCrutCher\n#westandtogether #blacklivesmatter #unite4justice #novem ber8\n#elections2016 #black #melanin #blackisbeautiful #blacklivesmatter\n#blackgirlmagic #USA #blackandproud #democrat #republioan\n#Africanamerican #unite4justice #vote #breakingnews
# 4  Black girls are the definition of national greatness.
# 5  Imma stay here comfy and untouched, yet working hard and caring for my\nown and staring at all what's going on.\n\nStay Black, stay strong\n\n#blacklivesmatter #unite4justice #november8 #election52016 #black #melanin\n#blackisbeautiful #blacklivesmatter #blackgirlmagic #USA #blackandproud\n#democrat #republican #Africanamerican #unite4justice #vote #breakingnews\n#melaninqueen #dope #beautiful #wakeup #wewillsurvive #organize\n##joshuabeal #altonsterling #TerenceCrutcher #westandtogether
# 6  There is a disgusting video Circulating on the internet which shows an\nunidentified white cop rape a helpless Black teen. Shameless White Cop\nRapes Black Teen | BM BM
# 7  Art imitates life art. This photo is great.
# 8  In America, racial oppression and racism were never an ancient history.
# 9  Donald John Trump was elected the 45th president of the United States on\nTuesday! Today some massive crowds of libtards marched in NYC against\nelection of Donald Trump.\n\nCome to Trump Tower (725 5th Ave) on Saturday to show Mr. Trump there\nactually ARE people in NY who voted for him! Support Trump in NYC
