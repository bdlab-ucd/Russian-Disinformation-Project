# %%
# set the matplotlib backend so figures can be saved in the background
import matplotlib
# matplotlib.use("Agg")

# import the necessary packages
import time
import pandas as pd
import seaborn as sn
import keras
import os
import cv2
import pickle
import random
import argparse
import numpy as np
from imutils import paths
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from keras.layers import Dense
from keras.preprocessing.image import img_to_array
from keras.models import Model
from keras.optimizers import Adam
from keras.optimizers import Nadam
from keras.optimizers import RMSprop
from keras.losses import logcosh, binary_crossentropy
from keras.activations import relu, elu, sigmoid
from keras.preprocessing.image import ImageDataGenerator
# import matplotlib
# matplotlib.use("Agg")
# Out:
# Using TensorFlow backend.

# %%
# initialize the number of epochs to train for, initial learning rate,
# batch size, and image dimensions
EPOCHS = 200
INIT_LR = 1e-2
BS = 64
IMAGE_DIMS = (224, 224, 3)

# %%
from imutils import paths

imagePaths = sorted(list(paths.list_images("anger_classification_majority_trimmed")))
random.seed(42)
random.shuffle(imagePaths)
imagePaths
# Out:
# ['anger_classification_majority_trimmed\\anger\\anger_664.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_667.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_708.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_556.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_455.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_16.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_357.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_779.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_65.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_210.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_290.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_35.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_485.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_779.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_29.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_167.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_316.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_483.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_80.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_189.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_172.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_704.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_249.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_489.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_366.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_139.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_514.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_8.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_747.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_99.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_388.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_283.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_434.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_358.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_264.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_179.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_566.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_547.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_545.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_59.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_352.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_158.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_130.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_700.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_447.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_638.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_265.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_199.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_163.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_438.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_764.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_128.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_700.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_49.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_762.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_218.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_135.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_702.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_275.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_224.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_187.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_619.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_570.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_197.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_259.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_403.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_176.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_547.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_325.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_399.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_214.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_453.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_499.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_140.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_83.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_420.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_41.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_51.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_432.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_382.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_698.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_594.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_599.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_253.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_530.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_15.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_450.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_335.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_735.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_452.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_12.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_528.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_200.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_350.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_54.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_747.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_285.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_251.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_464.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_63.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_507.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_442.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_278.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_424.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_625.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_421.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_423.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_91.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_435.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_191.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_724.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_445.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_93.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_578.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_289.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_546.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_67.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_217.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_600.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_293.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_688.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_630.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_744.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_262.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_433.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_23.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_129.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_291.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_726.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_712.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_633.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_32.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_287.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_701.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_620.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_366.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_446.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_540.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_707.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_45.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_317.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_768.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_11.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_505.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_706.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_770.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_215.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_763.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_116.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_615.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_299.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_560.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_37.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_241.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_364.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_426.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_138.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_476.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_542.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_606.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_261.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_695.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_604.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_126.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_16.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_118.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_151.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_565.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_292.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_22.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_525.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_362.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_571.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_515.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_127.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_154.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_574.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_239.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_102.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_153.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_737.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_402.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_773.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_757.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_208.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_437.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_157.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_469.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_93.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_650.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_111.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_180.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_151.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_283.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_276.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_624.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_643.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_416.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_28.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_646.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_20.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_705.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_720.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_395.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_105.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_162.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_733.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_24.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_369.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_598.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_358.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_194.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_632.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_127.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_675.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_769.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_593.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_187.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_87.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_147.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_140.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_478.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_439.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_188.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_129.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_221.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_6.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_12.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_668.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_211.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_356.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_106.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_336.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_443.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_564.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_119.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_383.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_479.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_734.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_427.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_406.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_731.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_81.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_466.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_247.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_386.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_714.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_609.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_468.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_365.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_689.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_674.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_589.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_226.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_626.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_532.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger
jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_36.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_745.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_14.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_482.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_391.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_207.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_327.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_759.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_379.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_617.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_235.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_238.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_781.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_7.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_63.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_166.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_551.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_468.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_158.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_512.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_539.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_171.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_145.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_268.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_767.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_594.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_629.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_530.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_360.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_347.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_515.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_193.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_734.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_687.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_706.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_368.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_250.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_148.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_14.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_350.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_150.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_718.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_607.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_377.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_263.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_430.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_307.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_497.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_571.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_9.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_359.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_645.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_582.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_641.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_8.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_88.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_406.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_275.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_579.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_702.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_208.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_470.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_276.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_113.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_343.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_620.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_742.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_348.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_516.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_225.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_244.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_95.jpg',
# ...
#  'anger_classification_majority_trimmed\\anger\\anger_772.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_585.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_99.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_544.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_257.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_666.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_347.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_699.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_388.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_775.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_312.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_524.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_568.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_419.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_521.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_684.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_431.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_498.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_196.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_451.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_487.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_109.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_412.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_634.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_565.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_555.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_44.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_708.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_345.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_59.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_418.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_136.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_62.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_209.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_488.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_729.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_376.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_107.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_740.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_449.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_321.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_363.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_379.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_193.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_168.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_281.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_422.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_464.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_444.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_722.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_236.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_386.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_121.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_738.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_72.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_578.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_635.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_27.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_496.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_759.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_220.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_658.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_657.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_252.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_438.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_101.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_62.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_776.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_736.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_561.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_192.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_519.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_715.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_597.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_214.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_266.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_25.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_671.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_232.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_772.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_516.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_126.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_91.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_135.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_7.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_533.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_161.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_698.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_435.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_420.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_146.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_713.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_87.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_436.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_333.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_173.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_164.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_330.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_455.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_161.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_9.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_354.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_182.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_98.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_409.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_716.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_517.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_293.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_40.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_526.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_338.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_307.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_679.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_523.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_589.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_581.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_691.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_426.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_195.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_598.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_456.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_644.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_74.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_122.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_617.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_672.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_670.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_529.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_273.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_250.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_683.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_471.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_608.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_724.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_714.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_408.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_237.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_124.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_576.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_50.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_35.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_313.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_319.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_300.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_654.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_132.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_601.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_776.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_64.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_595.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_727.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_165.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_288.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_181.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_458.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_90.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_482.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_422.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_651.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_500.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_637.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_629.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_405.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_206.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_686.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_116.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_31.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_637.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_514.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_229.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_322.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_346.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_162.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_289.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_155.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_481.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_528.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_599.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_616.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_474.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_480.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_705.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_744.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_75.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_239.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_738.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_354.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_375.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_434.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_622.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_172.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_597.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_218.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_674.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_407.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_349.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_314.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_693.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_756.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_404.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_503.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_351.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_318.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_676.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_545.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_579.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_111.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_100.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_681.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_686.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_17.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_326.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_89.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_337.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_511.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_536.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_570.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_81.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_244.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_557.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_398.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_603.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_732.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_160.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_479.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_563.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_217.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_761.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_146.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_663.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_506.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_216.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_92.jpg',
#  'anger_classification_majority_trimmed\\non_anger\\non_anger_270.jpg',
#  'anger_classification_majority_trimmed\\anger\\anger_390.jpg',
#  ...]

# %%
from keras.preprocessing.image import img_to_array

data = []
labels = []

# loop over the input images
for imagePath in imagePaths:
    # load the image, pre-process it, and store it in the data list
    image = cv2.imread(imagePath)
    image = cv2.resize(image, (IMAGE_DIMS[1], IMAGE_DIMS[0]))
    image = img_to_array(image)
    data.append(image)

    # extract the class label from the image path and update the
    # labels list
    label = imagePath.split(os.path.sep)[-2]
    labels.append(label)

# %%
# scale the raw pixel intensities to the range [0, 1]
data = np.array(data, dtype="float") / 255.0
labels = np.array(labels)
print("[INFO] data matrix: {:.2f}MB".format(
    data.nbytes / (1024 * 1000.0)))
# Out:
# [INFO] data matrix: 1838.09MB

# %%
from sklearn.preprocessing import LabelBinarizer

# binarize the labels
lb = LabelBinarizer()
labels = lb.fit_transform(labels)

# %%
from sklearn.model_selection import train_test_split

# partition the data into training and testing splits using 80% of
# the data for training and the remaining 20% for testing
(trainX, testX, trainY, testY) = train_test_split(data,
    labels, test_size=0.2, random_state=42)

# %%
# construct the image generator for data augmentation
aug = ImageDataGenerator(rotation_range=25, width_shift_range=0.1,
    height_shift_range=0.1, shear_range=0.2, zoom_range=0.2,
    horizontal_flip=True, fill_mode="nearest")

# %%
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dropout
from keras.layers.core import Dense
from keras import backend as K

class SmallerVGGNet:
    @staticmethod
    def build(width, height, depth, classes):
        # initialize the model along with the input shape to be
        # "channels last" and the channels dimension itself
        model = Sequential()
        inputShape = (height, width, depth)
        chanDim = -1

        # if we are using "channels first", update the input shape
        # and channels dimension
        if K.image_data_format() == "channels_first":
            inputShape = (depth, height, width)
            chanDim = 1

        # CONV => RELU => POOL
        model.add(Conv2D(32, (3, 3), padding="same",
            input_shape=inputShape))
        model.add(Activation("relu"))
        model.add(BatchNormalization(axis=chanDim))
        model.add(MaxPooling2D(pool_size=(3, 3)))
        model.add(Dropout(0.25))

        # (CONV => RELU) * 2 => POOL
        model.add(Conv2D(64, (3, 3), padding="same"))
        model.add(Activation("relu"))
        model.add(BatchNormalization(axis=chanDim))
        model.add(Conv2D(64, (3, 3), padding="same"))
        model.add(Activation("relu"))
        model.add(BatchNormalization(axis=chanDim))
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(0.25))

        # (CONV => RELU) * 2 => POOL
        model.add(Conv2D(128, (3, 3), padding="same"))
        model.add(Activation("relu"))
        model.add(BatchNormalization(axis=chanDim))
        model.add(Conv2D(128, (3, 3), padding="same"))
        model.add(Activation("relu"))
        model.add(BatchNormalization(axis=chanDim))
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(0.25))
        
        # (CONV => RELU) * 2 => POOL
        model.add(Conv2D(256, (3, 3), padding="same"))
        model.add(Activation("relu"))
        model.add(BatchNormalization(axis=chanDim))
        model.add(Conv2D(256, (3, 3), padding="same"))
        model.add(Activation("relu"))
        model.add(BatchNormalization(axis=chanDim))
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Conv2D(256, (3, 3), padding="same"))
        model.add(Activation("relu"))
        model.add(BatchNormalization(axis=chanDim))
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Conv2D(256, (3, 3), padding="same"))
        model.add(Activation("relu"))
        model.add(BatchNormalization(axis=chanDim))
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(0.25))

        # first (and only) set of FC => RELU layers
        model.add(Flatten())
        model.add(Dense(1024))
        model.add(Activation("relu"))
        model.add(BatchNormalization())
        model.add(Dropout(0.5))

        # softmax classifier
        model.add(Dense(classes))
        model.add(Activation("softmax"))

        # return the constructed network architecture
        return model

# %%
print("[INFO] compiling model...")
model = SmallerVGGNet.build(width=IMAGE_DIMS[1], height=IMAGE_DIMS[0],
    depth=IMAGE_DIMS[2], classes=len(lb.classes_))
opt = Adam(lr=INIT_LR, decay=INIT_LR / EPOCHS)
model.compile(loss="sparse_categorical_crossentropy", optimizer=opt,
    metrics=["accuracy"])
print("[INFO] done compiling.")
# Out:
# [INFO] compiling model...
# [INFO] done compiling.

# %%
import tensorflow as tf

config = tf.compat.v1.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.3
tf.compat.v1.keras.backend.set_session(tf.compat.v1.Session(config=config))

# %%
# train the network
print("[INFO] training network...")
H = model.fit_generator(
    aug.flow(trainX, trainY, batch_size=BS),
    validation_data=(testX, testY),
    steps_per_epoch=len(trainX) // BS,
    epochs=EPOCHS, verbose=1)#, class_weight={0:3, 1:1})

# save the model to disk
print("[INFO] serializing network...")
model.save("anger_trimmed_SmallVGG_200_epochs.model")
# 19/19 [==============================] - 9s 456ms/step - loss: 0.4110 - accuracy: 0.8097 - val_loss: 0.7503 - val_accuracy: 0.6454
# Epoch 193/200
# 19/19 [==============================] - 9s 480ms/step - loss: 0.3722 - accuracy: 0.8232 - val_loss: 1.0179 - val_accuracy: 0.6262
# Epoch 194/200
# 19/19 [==============================] - 9s 471ms/step - loss: 0.3891 - accuracy: 0.8162 - val_loss: 0.9863 - val_accuracy: 0.6518
# Epoch 195/200
# 19/19 [==============================] - 9s 466ms/step - loss: 0.3387 - accuracy: 0.8331 - val_loss: 1.5076 - val_accuracy: 0.6518
# Epoch 196/200
# 19/19 [==============================] - 9s 467ms/step - loss: 0.3775 - accuracy: 0.8347 - val_loss: 1.2308 - val_accuracy: 0.5655
# Epoch 197/200
# 19/19 [==============================] - 9s 466ms/step - loss: 0.3682 - accuracy: 0.8263 - val_loss: 1.2311 - val_accuracy: 0.5016
# Epoch 198/200
# 19/19 [==============================] - 9s 471ms/step - loss: 0.3614 - accuracy: 0.8373 - val_loss: 0.8592 - val_accuracy: 0.6677
# Epoch 199/200
# 19/19 [==============================] - 9s 465ms/step - loss: 0.3518 - accuracy: 0.8322 - val_loss: 1.8663 - val_accuracy: 0.4920
# Epoch 200/200
# 19/19 [==============================] - 9s 467ms/step - loss: 0.3671 - accuracy: 0.8179 - val_loss: 1.6026 - val_accuracy: 0.5559
# [INFO] serializing network...

# %%
plt.style.use("ggplot")
# %matplotlib inline
plt.figure()
N = EPOCHS
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="upper left")
plt.show()
plt.savefig("anger_trimmed_SmallVGG_200_epochs.png")

# %%
from sklearn.datasets import make_circles
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from keras.models import Sequential
from keras.layers import Dense
 

# predict probabilities for test set
yhat_probs = model.predict(testX, verbose=0)
# predict crisp classes for test set
yhat_classes = model.predict_classes(testX, verbose=0)

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sn

classif_report = classification_report(testY, yhat_classes, target_names=['anger', 'non-anger'])
print('Classification report: ')
print('---------------------------------------------------------- ')
print(classif_report)

print('---------------------------------------------------------- ')
# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(testY, yhat_classes)
print('Accuracy score: %f' % accuracy)
# precision tp / (tp + fp)
precision = precision_score(testY, yhat_classes)
print('Precision score: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(testY, yhat_classes)
print('Recall score: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(testY, yhat_classes)
print('F1 score: %f' % f1)
print('---------------------------------------------------------- ')

# confusion matrix
labels = ['anger', 'none']
matrix = confusion_matrix(testY, yhat_classes)
print('Confusion matrix: ')
print(matrix)
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(matrix)
plt.title('Confusion Matrix')
fig.colorbar(cax)
ax.set_xticklabels([''] + labels)
ax.set_yticklabels([''] + labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.savefig('confusion_matrix_anger_trimmed_SmallVGG_200_epochs.png')
plt.show()
print(matrix)
# Out:
# Classification report:
# ----------------------------------------------------------
#               precision    recall  f1-score   support
#
#        anger       0.52      0.88      0.65       148
#    non-anger       0.71      0.27      0.39       165
#
#     accuracy                           0.56       313
#    macro avg       0.61      0.57      0.52       313
# weighted avg       0.62      0.56      0.51       313
#
# ----------------------------------------------------------
# Accuracy score: 0.555911
# Precision score: 0.709677
# Recall score: 0.266667
# F1 score: 0.387665
# ----------------------------------------------------------
# Confusion matrix:
# [[130  18]
#  [121  44]]
# [[130  18]
#  [121  44]]
